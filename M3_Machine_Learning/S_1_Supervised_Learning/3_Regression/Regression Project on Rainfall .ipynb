# %% [markdown]
# <div style="position: relative; width: 100%; height: 100vh; padding: 50px; box-sizing: border-box;">
#     <!-- Logo positioned in the right corner -->
#     <img src="logo.png" style="position: absolute; top: 10px; right: 10px; width: 100px;"/>
#
#    <!-- Proprietary Content -->
#    <div style="position: absolute; bottom: px5; left: 5%; transform: translateX(-50%); color: grey; text-align: left;font-style: italic">
#    <p>Proprietary content. © 10xTechClub. All Rights Reserved. Unauthorized use or distribution prohibited.</p>
#    </div>
# </div>

# %% [markdown]
# <h1 style="color:purple; text-align:center; font-weight:bold; font-size:40px;">☔ Predicting Umbrellas Sold Based on Rainfall 🌧️</h1>

# %% [markdown]
# # What is Regression?
# Regression is a type of mathematical and statistical technique used to find relationships between different variables. Simply put, it helps us understand how one thing (like rainfall) affects another thing (like umbrella sales). In the world of machine learning and data science, we use regression to predict future outcomes based on past data.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # **Where Do We Use Regression?**
#
# ### Regression is used in many real-life situations to predict future trends or outcomes. Some examples include:
#
#  - **Business:** Predicting future sales based on past data (like our umbrella sales example).
#  - **Weather:** Predicting future temperatures or rainfall based on historical weather data.
#  - **Finance:** Predicting stock prices or a company's future earnings.
#  - **Healthcare:** Predicting a patient's risk of developing a disease based on their medical history.
#  - **Education:** Predicting a student's grades based on study hours and other factors.
#
# ![image-5.png](attachment:image-5.png)
#
# # **Understanding Dependent and Independent Variables in Linear Regression**
#
#  - **Dependent Variable (Target Variable):** This is the variable you're trying to predict or explain. It's the outcome that depends on other factors. In a linear regression model, it's usually denoted by \( y \).
#
#  - **Independent Variable (Predictor Variable):** This is the variable that you use to make predictions about the dependent variable. It's the factor that influences or predicts the outcome. In linear regression, it's typically denoted by \( x \).
#
#  In essence, the dependent variable is what you want to understand or forecast, while the independent variables are the factors you believe influence or determine the outcome.
#
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# ## Welcome to our project! 🎉 Today, we will explore how rainfall affects the number of umbrellas sold using a simple linear regression model.

# %% [markdown]
# ## <span style="color:red; font-weight:bold;">🔧 Step 1: Importing Libraries 📚</span>
# ### First, let's bring in some important libraries that will help us with data handling and creating a predictive model! We'll use:
# - **pandas** to handle our dataset.
# - **matplotlib** to visualize the data with cool graphs. 📊
# - **sklearn** to perform Linear Regression (don't worry, we'll explain this later!). 🤓

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import numpy as np

# %% [markdown]
# ## <span style="color:red; font-weight:bold;">📂 Step 2: Loading the Data 🌍</span>
# ### Now, let's read our **Rainfall vs Umbrellas Sold** data using `pandas`. Each row in the dataset shows:
# - **Rainfall (mm)**: The amount of rainfall recorded.
# In this dataset,
# **Rainfall (mm)** is chosen as the X-axis (independent variable) because it is the factor that influences the outcome. As rainfall increases, the number of umbrellas sold typically changes, making it the cause or predictor.
#
#
# - **Umbrellas Sold**: The number of umbrellas sold based on the amount of rain. ☂️
# **Umbrellas Sold** is placed on the Y-axis (dependent variable) because it depends on the amount of rainfall. The more it rains, the more umbrellas people are likely to buy. Therefore, umbrella sales are the result or response to rainfall, making them the dependent variable.

# %%
data = pd.read_csv("rainfall_data.csv")

# %%
data
# Out:
#     Rainfall  Umbrellas Sold
# 0       20.0            22.0
# 1       40.0            45.0
# 2       25.0            27.0
# 3       30.0            33.0
# 4       50.0            55.0
# 5       70.0            80.0
# 6       80.0            88.0
# 7       60.0            67.0
# 8       90.0           100.0
# 9      100.0           110.0
# 10      15.0            20.0
# 11      35.0            38.0
# 12      45.0            48.0
# 13      55.0            58.0
# 14      65.0            68.0
# 15      75.0            78.0
# 16      85.0            87.0
# 17      95.0            97.0
# 18     110.0           115.0
# 19     120.0           125.0
# 20      22.0            23.0
# 21      42.0            43.0
# 22      27.0            29.0
# 23      32.0            35.0
# 24      52.0            58.0
# 25      72.0            83.0
# 26      82.0            90.0
# 27      62.0            69.0
# 28      92.0           103.0
# 29     102.0           113.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## <span style="color:red; font-weight:bold;">🤖 Step 3: Creating the Model 🧠</span>
# ### We are now going to prepare our **Linear Regression** model. In this case:
# - **X (Rainfall)**: The amount of rainfall.
# - **y (Umbrellas Sold)**: The number of umbrellas sold when it rained.

# %%
X = data['Rainfall'].values.reshape(-1,1)

# %%
y = data['Umbrellas Sold'].values

# %% [markdown]
# ## Linear Regression
#
# Linear regression is a statistical method used to model the relationship between a dependent variable and one or more independent variables. It aims to find the best-fitting straight line that minimizes the difference between the predicted and actual values.
#
# ### Simple Linear Regression
#
# In simple linear regression, there is one independent variable and the relationship is modeled with a straight line. The formula for simple linear regression is:
#
# Linear regression is commonly used for predictive modeling, trend analysis, and understanding the impact of various factors.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## <span style="color:red; font-weight:bold;">🏋️‍♂️ Step 4: Training the Model 🎯</span>
# ### Now, let’s **train** our model! We will use the amount of **rainfall** and corresponding **umbrellas sold** to teach our model how these two are related.

# %%
model = LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## <span style="color:red; font-weight:bold;">🔮 Step 5: Predicting Umbrellas Sales for Future Rainfall 🚀</span>
# ### Our model is now trained! Let's predict how many umbrellas would be sold for future rainfall amounts from **110mm to 130mm**.

# %%
future_rainfall = np.array(range(110, 131)).reshape(-1, 1)

# %% [markdown]
# ## <span style="color:red; font-weight:bold;">📈 Step 6: Analyzing the Trend 🔍</span>
# ### The model will now predict the number of umbrellas that will be sold for different rainfall amounts. Let's store these predictions in a variable.

# %%
predicted_sales = model.predict(future_rainfall)

# %%
predicted_sales
# Out:
# array([118.20637319, 119.26788436, 120.32939553, 121.3909067 ,
#        122.45241787, 123.51392904, 124.57544021, 125.63695138,
#        126.69846255, 127.75997372, 128.82148489, 129.88299606,
#        130.94450723, 132.0060184 , 133.06752957, 134.12904074,
#        135.19055191, 136.25206307, 137.31357424, 138.37508541,
#        139.43659658])

# %% [markdown]
# ## <span style="color:red; font-weight:bold;">🎨 Step 7: Visualizing the Data 📊</span>
# ### Let's plot the data! Here's what we're doing:
# - **Blue dots** represent the actual data of rainfall vs umbrellas sold.
# - The **Red line** shows the regression line, indicating the trend between rainfall and umbrellas sold.
# - The **Green line** represents our future predictions from **110mm to 130mm** rainfall.

# %%
plt.scatter(X, y, color='blue', label='Actual Data')
plt.plot(X, model.predict(X), color='red', label='Regression Line')
plt.plot(future_rainfall, predicted_sales, color='green', label='Future Predictions')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Umbrellas Sold')
plt.title('Rainfall vs Umbrellas Sold')
plt.legend()
plt.show()

# %% [markdown]
# ## <span style="color:red; font-weight:bold;">🎉 Congratulations! 🎉</span>
# ## You've just completed a **Rainfall Prediction** project using **Linear Regression**! Now you know how to:
# ### - Import and use essential libraries like `pandas`, `matplotlib`, and `sklearn`.
# ### - Train a **Linear Regression** model on historical data to predict future outcomes.
# ### - Visualize both actual and predicted data using beautiful graphs!
#
# ### Keep experimenting and exploring, and soon, you'll be a master at predicting all sorts of things! 🚀
#
# ### Remember, the future is in your hands — keep learning and creating! 🧑‍💻🌟

# %% [markdown]
# ## <span style="color:red; font-weight:bold;">Conclusion </span>
#
#
#
# 1. **Connected Changes**: When one thing (like Rainfall or Year) changes, it affects something else (like Umbrellas Sold or Temperature). Linear regression helps us see how they are connected.
#
# 2. **Straight-Line Pattern**: We expect the relationship to follow a straight line, where one thing increases or decreases along with the other.
#
# 3. **Making Predictions**: Linear regression is great for guessing future numbers, like how many umbrellas people will buy if it rains more or what the temperature might be in future years.
#
# 4. **Easy to Understand**: The model is simple and shows how much one thing changes when another changes, making it easy to explain and use.
