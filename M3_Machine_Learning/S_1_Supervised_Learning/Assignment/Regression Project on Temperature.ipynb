# %% [markdown]
# <div style="position: relative; width: 100%; height: 100vh; padding: 50px; box-sizing: border-box;">
#     <!-- Logo positioned in the right corner -->
#     <img src="logo.png" style="position: absolute; top: 10px; right: 10px; width: 100px;"/>
#
#    <!-- Proprietary Content -->
#    <div style="position: absolute; bottom: px5; left: 5%; transform: translateX(-50%); color: grey; text-align: left;font-style: italic">
#    <p>Proprietary content. © 10xTechClub. All Rights Reserved. Unauthorized use or distribution prohibited.</p>
#    </div>
# </div>

# %% [markdown]
# <h1 style="color:purple; text-align:center; font-weight:bold; font-size:40px;">🌡️ Predicting Future Temperatures 📈</h1>

# %% [markdown]
# ## <span style="color:red; font-weight:bold;">🔧 Step 1: Importing Libraries 📚</span>
# ### First, let's bring in some important libraries that will help us with data handling and creating a predictive model! We'll use:
# - **pandas** to handle our dataset.
# - **matplotlib** to visualize the data with cool graphs. 📊
# - **sklearn** to perform Linear Regression (don't worry, we'll explain this later!). 🤓

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import numpy as np

# %% [markdown]
# ## <span style="color:red; font-weight:bold;">📂 Step 2: Loading the Data 🌍</span>
# ### Now, let's read our data using `pandas`. The data contains the year and average temperature. Each row represents a different year and its corresponding average temperature across the world. Let's see what our data looks like! 👀

# %%
data= pd.read_csv("temperature_data.csv")

# %%
data
# Out:
#     Year  AverageTemperature
# 0   2000                16.4
# 1   2001                16.5
# 2   2002                16.8
# 3   2003                17.1
# 4   2004                17.0
# 5   2005                17.2
# 6   2006                17.4
# 7   2007                17.3
# 8   2008                17.6
# 9   2009                17.8
# 10  2010                17.5
# 11  2011                17.9
# 12  2012                18.0
# 13  2013                18.2
# 14  2014                18.1
# 15  2015                18.5
# 16  2016                18.3
# 17  2017                18.6
# 18  2018                18.7
# 19  2019                19.0
# 20  2020                19.2
# 21  2021                19.1
# 22  2022                19.3
# 23  2023                19.6
# 24  2024                19.8
# 25  2025                20.0

# %% [markdown]
# ## <span style="color:red; font-weight:bold;">🤖 Step 3: Creating the Model 🧠</span>
# ### We are now going to prepare our **Linear Regression** model. The independent variable here is the **Year** (X), and the dependent variable is the **Average Temperature** (y). In simple words:
# - **X (Year)**: The year we want to predict the temperature for.
# - **y (Temperature)**: The temperature in that year.
#
# Year is chosen as the X-axis (independent variable) because it represents the time or progression of years, and it helps us predict future outcomes. The temperature is expected to change over time, so the year acts as the predictor.
#
# Average Temperature is placed on the Y-axis (dependent variable) because it is what we are trying to predict. The temperature depends on the year, and we are modeling how temperature trends change over time. Hence, temperature is the result or outcome based on the year, making it the dependent variable.

# %%
X=data['Year'].values.reshape(-1,1)

# %%
y= data['AverageTemperature'].values

# %% [markdown]
# ## Linear Regression
#
# Linear regression is a statistical method used to model the relationship between a dependent variable and one or more independent variables. It aims to find the best-fitting straight line that minimizes the difference between the predicted and actual values.
#
# ### Simple Linear Regression
#
# In simple linear regression, there is one independent variable and the relationship is modeled with a straight line. The formula for simple linear regression is:
#
#
# Linear regression is commonly used for predictive modeling, trend analysis, and understanding the impact of various factors.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## <span style="color:red; font-weight:bold;">🏋️‍♂️ Step 4: Training the Model 🎯</span>
# ### Now, let’s **train** our model! We are using the years and their respective average temperatures to make the model learn how to predict temperatures based on a given year.

# %%
model = LinearRegression()

# %% [markdown]
# ### `model.fit()` Method
#
# The `model.fit()` method is used to train a machine learning model on a given dataset. It adjusts the model's parameters to minimize the error between predicted and actual values.
#
# **Key Points:**
# - **Training**: Updates model parameters based on input data.
# - **Optimization**: Minimizes the loss function using optimization algorithms.
# - **Data Integration**: Uses training data to learn patterns and make predictions.
# - **Validation**: Can include validation data to tune the model and prevent overfitting.

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## <span style="color:red; font-weight:bold;">🔮 Step 5: Predicting Future Temperatures 🚀</span>
# ### Our model is now trained! Let's use it to predict future temperatures from the year **2021 to 2030**. These will be our predicted future temperatures based on past data.

# %%
future_years= np.array(range(2021,2031)).reshape(-1,1)

# %% [markdown]
# ## <span style="color:red; font-weight:bold;">📈 Step 6: Analyzing the Trend 🔍</span>
# ### The model will now predict the temperature for the upcoming years. Let's store these predictions in a variable and observe the changes in temperatures over time.

# %%
predicted_temperatures= model.predict(future_years)

# %%
predicted_temperatures
# Out:
# array([19.23528205, 19.36748718, 19.49969231, 19.63189744, 19.76410256,
#        19.89630769, 20.02851282, 20.16071795, 20.29292308, 20.42512821])

# %% [markdown]
# ## <span style="color:red; font-weight:bold;">🎨 Step 7: Visualizing the Data 📊</span>
# ### Let's plot the data! Here's what we're doing:
# - **Blue dots** represent the actual data from the past.
# - The **Red line** shows the regression line, which is the trend line based on past data.
# - The **Green line** represents our future predictions from the year 2021 to 2030.
# - Watch how the temperatures change over time! 🌡️

# %%
plt.scatter(X,y, color='blue', label='Actual Data')
plt.plot(X,model.predict(X), color='red', label='Regression Line')
plt.plot(future_years,predicted_temperatures,color='green', label='Future Predictions')
plt.xlabel('Year')
plt.ylabel('Average Temperature')
plt.title('Year vs Avg Temperature')
plt.legend()
plt.show()

# %% [markdown]
# ## <span style="color:red; font-weight:bold;">🎉 Congratulation! 🎉</span>
# ### You've just completed a **Temperature Prediction** project using **Linear Regression**! Now you know how to:
# - Import and use essential libraries like `pandas`, `matplotlib`, and `sklearn`.
# - Train a **Linear Regression** model on historical data to predict future outcomes.
# - Visualize both actual and predicted data using beautiful graphs!
#
# Keep experimenting and exploring, and soon, you'll be a master at predicting all sorts of things! 🚀
#
# Remember, the future is in your hands — keep learning and creating! 🧑‍💻🌟
#
# ## <span style="color:red; font-weight:bold;">Conclusion </span>
#
#
#
# 1. **Connected Changes**: When one thing (like Rainfall or Year) changes, it affects something else (like Umbrellas Sold or Temperature). Linear regression helps us see how they are connected.
#
# 2. **Straight-Line Pattern**: We expect the relationship to follow a straight line, where one thing increases or decreases along with the other.
#
# 3. **Making Predictions**: Linear regression is great for guessing future numbers, like how many umbrellas people will buy if it rains more or what the temperature might be in future years.
#
# 4. **Easy to Understand**: The model is simple and shows how much one thing changes when another changes, making it easy to explain and use.
