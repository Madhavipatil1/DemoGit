# %% [markdown]
# <h1 style="text-align:center; color:purple; font-weight:bold; font-size:50px;">
#     🌟 Ollama Language Model Project 🚀
# </h1>

# %% [markdown]
# ## **Understanding Important Concepts for the Ollama Language Model Project** 📚
#
# Before jumping into the coding part, let's first understand some of the key concepts that are important for this project.

# %% [markdown]
# ## <span style="color:red;">1. What is Ollama? 🤖</span>
#
# **Ollama** is a powerful language model designed to understand and generate human-like text. It works by predicting what comes next in a sentence based on the given input. In this project, we are using a specific Ollama model called **Mistral**. It helps answer questions, complete sentences, and generate meaningful text.
#
# *Example*:
# If you provide Ollama with the input "The capital of France is...", it will respond with "Paris."
#
# ![image.png](attachment:382ac18f-b556-4ee6-82ef-604ca72c620b.png)
#
#
#
# ## <span style="color:red;">2. What is a Language Model (LLM)? 🧠</span>
#
# A **Language Model (LLM)** is a type of artificial intelligence that understands and generates natural language (the way humans talk or write). These models are trained on vast amounts of text data, and they learn to predict the next word in a sentence or respond to user inputs.
#
# *In this project*, we're using a **Large Language Model** (LLM) like Ollama to complete tasks that involve language understanding.
#
# ![image.png](attachment:f3383561-2f2d-4085-bc21-f3ad4a813416.png)
#
#
# ## <span style="color:red;">3. What is LangChain? 🔗</span>
#
# **LangChain** is a tool that allows developers to work with large language models in an easy and effective way. It helps connect different language models (like Ollama) and chain them together for more complex tasks. In this project, the **LangChain_Community** package will help us access the Ollama model and work with it.
#
# ![image.png](attachment:190e4ab8-155a-449a-ae54-bfc147d64754.png)
#
#
#
# ## <span style="color:red;">4. What is a Python Library? 📦</span>
#
# A **Python Library** is a collection of pre-written code that you can use to perform specific tasks without writing everything from scratch. Libraries like **Ollama** and **LangChain_Community** make it easier to use language models. Instead of writing complex code, you can import these libraries and use their functions directly.
#
#
# ## <span style="color:red;">5. What is Time Measurement in Python? ⏱️</span>
#
# **Time Measurement** in Python is used to calculate how long it takes for a piece of code to run. In this project, we use the `time` module to measure the performance of the code. This helps us understand if our code is running efficiently or if it needs optimization.

# %% [markdown]
# # Implementaion of Project

# %% [markdown]
# ## 1. Installing Required Libraries 📦
#
# * This installs the required libraries from the file `GenAIrequirements.txt`. This file contains a list of all the necessary packages for this project.
#
# * Installs the `langchain_community` package, which allows us to use language models like Ollama for advanced AI tasks.
#
# * Installs the `Ollama` package. This is used to work with the Ollama language models, such as the `mistral` model in this project.
#
# * A second installation command for `langchain_community` using `pip3`, ensuring it works with Python 3 versions.

# %%
# !pip install GenAIrequirements.txt
# Out:
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\madhavi\anaconda3\lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement GenAIrequirements.txt (from versions: none)
# ERROR: No matching distribution found for GenAIrequirements.txt
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\madhavi\anaconda3\lib\site-packages)

# %% [markdown]
# # 2. Importing and Initializing Ollama Model 🚀
#
# * Imports the `Ollama` model from the `langchain_community` package, allowing us to use the language model in the project.

# %%
# !pip install langchain_community
# Out:
# Requirement already satisfied: langchain_community in c:\users\madhavi\anaconda3\lib\site-packages (0.3.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\madhavi\anaconda3\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: langchain<0.4.0,>=0.3.0 in c:\users\madhavi\anaconda3\lib\site-packages (from langchain_community) (0.3.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\madhavi\anaconda3\lib\site-packages (from langchain_community) (3.10.3)
# Requirement already satisfied: requests<3,>=2 in c:\users\madhavi\anaconda3\lib\site-packages (from langchain_community) (2.28.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.112 in c:\users\madhavi\anaconda3\lib\site-packages (from langchain_community) (0.1.125)
# Requirement already satisfied: numpy<2,>=1 in c:\users\madhavi\anaconda3\lib\site-packages (from langchain_community) (1.24.3)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.0 in c:\users\madhavi\anaconda3\lib\site-packages (from langchain_community) (0.3.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\madhavi\anaconda3\lib\site-packages (from langchain_community) (1.4.39)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\madhavi\anaconda3\lib\site-packages (from langchain_community) (8.5.0)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\madhavi\anaconda3\lib\site-packages (from langchain_community) (2.5.2)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\madhavi\anaconda3\lib\site-packages (from langchain_community) (6.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\madhavi\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.0.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\madhavi\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.0.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\madhavi\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.3.6)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\madhavi\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\madhavi\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\madhavi\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.9.4)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\madhavi\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (21.4.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\madhavi\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\madhavi\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.22.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in c:\users\madhavi\anaconda3\lib\site-packages (from langchain<0.4.0,>=0.3.0->langchain_community) (0.3.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\madhavi\anaconda3\lib\site-packages (from langchain<0.4.0,>=0.3.0->langchain_community) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\madhavi\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.0->langchain_community) (4.12.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\madhavi\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.0->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\madhavi\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.0->langchain_community) (24.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\madhavi\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.112->langchain_community) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\madhavi\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.112->langchain_community) (3.10.7)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\madhavi\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (1.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\madhavi\anaconda3\lib\site-packages (from requests<3,>=2->langchain_community) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\madhavi\anaconda3\lib\site-packages (from requests<3,>=2->langchain_community) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\madhavi\anaconda3\lib\site-packages (from requests<3,>=2->langchain_community) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\madhavi\anaconda3\lib\site-packages (from requests<3,>=2->langchain_community) (2.0.4)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\madhavi\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (1.1.1)
# Requirement already satisfied: sniffio in c:\users\madhavi\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain_community) (1.2.0)
# Requirement already satisfied: anyio in c:\users\madhavi\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain_community) (3.5.0)
# Requirement already satisfied: httpcore==1.* in c:\users\madhavi\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain_community) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\madhavi\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain_community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\madhavi\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.0->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\madhavi\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.0->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\madhavi\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.0->langchain_community) (2.23.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\madhavi\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (0.4.3)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\madhavi\anaconda3\lib\site-packages)

# %%
# !pip install Ollama
# Out:
# Requirement already satisfied: Ollama in c:\users\madhavi\anaconda3\lib\site-packages (0.3.3)
# Requirement already satisfied: httpx<0.28.0,>=0.27.0 in c:\users\madhavi\anaconda3\lib\site-packages (from Ollama) (0.27.0)
# Requirement already satisfied: sniffio in c:\users\madhavi\anaconda3\lib\site-packages (from httpx<0.28.0,>=0.27.0->Ollama) (1.2.0)
# Requirement already satisfied: idna in c:\users\madhavi\anaconda3\lib\site-packages (from httpx<0.28.0,>=0.27.0->Ollama) (3.3)
# Requirement already satisfied: httpcore==1.* in c:\users\madhavi\anaconda3\lib\site-packages (from httpx<0.28.0,>=0.27.0->Ollama) (1.0.5)
# Requirement already satisfied: anyio in c:\users\madhavi\anaconda3\lib\site-packages (from httpx<0.28.0,>=0.27.0->Ollama) (3.5.0)
# Requirement already satisfied: certifi in c:\users\madhavi\anaconda3\lib\site-packages (from httpx<0.28.0,>=0.27.0->Ollama) (2022.9.14)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\madhavi\anaconda3\lib\site-packages (from httpcore==1.*->httpx<0.28.0,>=0.27.0->Ollama) (0.14.0)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\madhavi\anaconda3\lib\site-packages)

# %% [markdown]
# Installations required
# 1. gpt4all
# 2. ollama from site
#
#
#
# Commands
# ollama list
# ollama run
# ollama pull

# %%
 # !pip3 install langchain_community
# Out:
# Requirement already satisfied: langchain_community in c:\users\madhavi\anaconda3\lib\site-packages (0.3.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\madhavi\anaconda3\lib\site-packages (from langchain_community) (1.4.39)
# Requirement already satisfied: numpy<2,>=1 in c:\users\madhavi\anaconda3\lib\site-packages (from langchain_community) (1.24.3)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\madhavi\anaconda3\lib\site-packages (from langchain_community) (2.5.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.112 in c:\users\madhavi\anaconda3\lib\site-packages (from langchain_community) (0.1.125)
# Requirement already satisfied: langchain<0.4.0,>=0.3.0 in c:\users\madhavi\anaconda3\lib\site-packages (from langchain_community) (0.3.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\madhavi\anaconda3\lib\site-packages (from langchain_community) (8.5.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\madhavi\anaconda3\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.0 in c:\users\madhavi\anaconda3\lib\site-packages (from langchain_community) (0.3.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\madhavi\anaconda3\lib\site-packages (from langchain_community) (3.10.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\madhavi\anaconda3\lib\site-packages (from langchain_community) (6.0)
# Requirement already satisfied: requests<3,>=2 in c:\users\madhavi\anaconda3\lib\site-packages (from langchain_community) (2.28.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\madhavi\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\madhavi\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.3.6)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\madhavi\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\madhavi\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.0.5)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\madhavi\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\madhavi\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.9.4)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\madhavi\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (21.4.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\madhavi\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\madhavi\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\madhavi\anaconda3\lib\site-packages (from langchain<0.4.0,>=0.3.0->langchain_community) (2.9.2)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in c:\users\madhavi\anaconda3\lib\site-packages (from langchain<0.4.0,>=0.3.0->langchain_community) (0.3.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\madhavi\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.0->langchain_community) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\madhavi\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.0->langchain_community) (4.12.2)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\madhavi\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.0->langchain_community) (24.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\madhavi\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.112->langchain_community) (3.10.7)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\madhavi\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.112->langchain_community) (0.27.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\madhavi\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (1.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\madhavi\anaconda3\lib\site-packages (from requests<3,>=2->langchain_community) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\madhavi\anaconda3\lib\site-packages (from requests<3,>=2->langchain_community) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\madhavi\anaconda3\lib\site-packages (from requests<3,>=2->langchain_community) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\madhavi\anaconda3\lib\site-packages (from requests<3,>=2->langchain_community) (1.26.11)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\madhavi\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (1.1.1)
# Requirement already satisfied: anyio in c:\users\madhavi\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain_community) (3.5.0)
# Requirement already satisfied: sniffio in c:\users\madhavi\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain_community) (1.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\madhavi\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain_community) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\madhavi\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain_community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\madhavi\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.0->langchain_community) (3.0.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\madhavi\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.0->langchain_community) (2.23.4)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\madhavi\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.0->langchain_community) (0.7.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\madhavi\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (0.4.3)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\madhavi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\madhavi\anaconda3\lib\site-packages)

# %%
from langchain_community.llms import Ollama

# %%
#ollama run mistral

# %% [markdown]
# ## 3. Measuring Execution Time ⏱️
#
# * The `time` module is imported to measure how long the code takes to run, which helps us understand the performance of our code.
#
# * Stores the current time in `start_time` before running the model. This is the star
#
# ## 4. Using the Ollama Model
#
# * Initializes the `Ollama` model with the name "mistral." This model is used to complete sentences and generate responses based on the input we provide.
#
# * Invokes (runs) the `Ollama` model with the sentence: "The first man on the moon was ...". The model completes the sentence, and the result is displayed on the screen.
#
#
# ## 5. Calculating and Displaying Execution Time
#
# * Stores the current time in `end_time` after the model has run. This is the ending point for measuring how long the code took to execute.
#
# * Calculates the difference between `end_time` and `start_time` to find the total time taken to run the code. This value is printed to show how many seconds it took for the code to execute.

# %%
import time

start_time = time.time()

llm = Ollama(model="mistral")
print(llm.invoke("The first man on the moon was ..."))

end_time = time.time()

print(f"The time it took to execute the code segment is {end_time - start_time} seconds.")
# Out:
#  Neil Armstrong. He took his famous "one small step for man, one giant leap for mankind" on July 20, 1969. Buzz Aldrin followed him as the second man to walk on the moon during the Apollo 11 mission.
# The time it took to execute the code segment is 102.42149615287781 seconds.

# %% [markdown]
# ## <span style="color:red;">Summary of Concepts 📝</span>
# - **🧠 Ollama**: The language model we are using for this project. It helps generate and understand human-like text.
# - **🤖 LLM (Language Model)**: A machine learning model that understands and generates human-like text based on input data.
# - **🔗 LangChain**: A tool that simplifies working with language models like Ollama by connecting them for complex tasks.
# - **📦 Python Libraries**: Pre-written code that helps us perform tasks quickly without writing everything from scratch.
# - **⏱️ Time Measurement**: Used to measure how long the code takes to run and check its performance.
# - **🖨️ `print()` Function**: Displays information to the user, such as outputs or results from the code.
# - **🛠️ `pip`**: A tool that allows us to install libraries and packages easily in Python.

# %% [markdown]
# ## <span style="color:red;">🎉 Congratulations! 🎉</span>
#
# You’ve successfully completed the **Ollama Language Model Project**! 🚀
# Great job on learning how to use advanced tools like **Ollama**, **LangChain**, and Python libraries to build an amazing AI-powered application. You've now taken your first steps into the exciting world of **AI and Language Models**! 🌟
#
# Keep experimenting, keep learning, and always stay curious! Who knows? The next big AI breakthrough might come from **YOU**! 💡
#
# 👏 **Well done, and keep up the fantastic work!** 👏
